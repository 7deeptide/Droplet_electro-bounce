# %%
f = open('workfile', 'w') # opens the workfile
f.write("This is a test \nand another test")
f.close()

# %%
f = open('workfile', 'r')
s = f.read()
print(s)
f.close()
# Out:
# This is a test
# and another test

# %%
"""Iterating over a file"""
f= open('workfile', 'r')
for line in f:
    print(line)
# Out:
# This is a test
#
# and another test

# %% [markdown]
# ## Standard Library
# "A portable way of using operating system dependant functionality"

# %%
import os
import numpy as np

datalist = os.listdir('pt_new/parallel_plates')
for csv in datalist:
    path = 'pt_new/parallel_plates/' + csv
    vars()["data" + csv[:-4]]= np.genfromtxt(path, dtype=float, delimiter=',', skip_header=1)

# %who
#if 3d, if 2drops
#make dictionary of experiemental parameters
# Out:
# a	 b	 csv	 data05697	 data05706	 data05707	 data05708	 data05709	 data05710
# data05711	 data05712	 data05713	 data05714	 data05715	 data05716	 data05717	 data05718	 data05719
# data1	 data2	 data3	 data5683	 data5695	 data5696	 datalist	 f	 i
# line	 np	 os	 path	 s
# array([[   1.   ,    1.374,   12.235,    0.671,    0.612,   90.2  ,
#            0.551,    9.   ,    1.096,    0.912,    0.916],
#        [   2.   ,    1.371,   12.026,    0.674,    0.616,   86.135,
#            0.475,   10.   ,    1.094,    0.914,    0.898],
#        [   3.   ,    1.381,   11.784,    0.666,    0.627,   84.22 ,
#            0.395,   11.   ,    1.062,    0.942,    0.867],
#        [   4.   ,    1.374,   11.542,    0.658,    0.612,   98.011,
#            0.415,   12.   ,    1.075,    0.93 ,    0.851],
#        [   5.   ,    1.358,   11.307,    0.692,    0.595,  115.506,
#            0.307,   13.   ,    1.163,    0.86 ,    0.828],
#        [   6.   ,    1.367,   11.093,    0.674,    0.575,   88.592,
# ...

# %%
"""
a=['1','2','3']
b=[10,20,30]
for i in range(1,3):
  vars()["data"+a[i]]=b[i]
print(data1, data2, data3)
"""
# Out:
# '\na=[\'1\',\'2\',\'3\']\nb=[10,20,30]\nfor i in range(1,3):\n  vars()["data"+a[i]]=b[i]\nprint(data1, data2, data3)\n'
